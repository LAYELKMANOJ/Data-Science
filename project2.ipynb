# %% [markdown]
# ## Flood Risk Prediction Model

# %% [markdown]
# ##  Import Libraries & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')


df_train = pd.read_csv("/kaggle/input/regression-with-a-flood-prediction-dataset/train.csv")
df_test = pd.read_csv("/kaggle/input/regression-with-a-flood-prediction-dataset/test.csv")
print(f"Train shape : {df_train.shape}")
print(f"Test shape  : {df_test.shape}")
df_train.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_57/2997840783.py in <cell line: 0>()
#       7
#       8
# ----> 9 df_train = pd.read_csv("/kaggle/input/regression-with-a-flood-prediction-dataset/train.csv")
#      10 df_test = pd.read_csv("/kaggle/input/regression-with-a-flood-prediction-dataset/test.csv")
#      11 print(f"Train shape : {df_train.shape}")
#
# ...
